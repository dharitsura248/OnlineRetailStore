# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import ipywidgets as widgets
from ipywidgets import interact
import pycaret
from pycaret.regression import *
from statsmodels.tsa.stattools import adfuller
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from IPython import display

# %%
df = pd.read_csv('../data/processed/Final_EDA.csv')

# %%
df.head()
# Out:
#    counts  TotalPrice  Average_Price  is_holiday  Pre_wk_orders  \
# 0   125.0     36227.9       289.8232         0.0            0.0
# 1   125.0     36227.9       289.8232         0.0            0.0
# 2   125.0     36227.9       289.8232         0.0            0.0
# 3   125.0     36227.9       289.8232         0.0            0.0
# 4   125.0     36227.9       289.8232         0.0            0.0
#
#    Pre_30_orders  Post_30_orders  Sales_boost Invoice StockCode  Quantity  \
# 0            0.0          2403.0          0.0  489434     85048      12.0
# 1            0.0          2403.0          0.0  489434    79323P      12.0
# 2            0.0          2403.0          0.0  489434    79323W      12.0
# 3            0.0          2403.0          0.0  489434     22041      48.0
# 4            0.0          2403.0          0.0  489434     21232      24.0
#
#    Price  Customer_Id  Hour  Month    Year  Day  Weeknumber
# 0   6.95      13085.0   7.0   12.0  2009.0  1.0        49.0
# 1   6.75      13085.0   7.0   12.0  2009.0  1.0        49.0
# 2   6.75      13085.0   7.0   12.0  2009.0  1.0        49.0
# 3   2.10      13085.0   7.0   12.0  2009.0  1.0        49.0
# 4   1.25      13085.0   7.0   12.0  2009.0  1.0        49.0

# %%
df.columns
# Out:
# Index(['counts', 'TotalPrice', 'Average_Price', 'is_holiday', 'Pre_wk_orders',
#        'Pre_30_orders', 'Post_30_orders', 'Sales_boost', 'Invoice',
#        'StockCode', 'Quantity', 'Price', 'Customer_Id', 'Hour', 'Month',
#        'Year', 'Day', 'Weeknumber'],
#       dtype='object')

# %%
df.dtypes
# Out:
# counts            float64
# TotalPrice        float64
# Average_Price     float64
# is_holiday        float64
# Pre_wk_orders     float64
# Pre_30_orders     float64
# Post_30_orders    float64
# Sales_boost       float64
# Invoice            object
# StockCode          object
# Quantity          float64
# Price             float64
# Customer_Id       float64
# Hour              float64
# Month             float64
# Year              float64
# Day               float64
# Weeknumber        float64
# dtype: object

# %%
df.isna().sum()
# Out:
# counts            0
# TotalPrice        0
# Average_Price     0
# is_holiday        0
# Pre_wk_orders     0
# Pre_30_orders     0
# Post_30_orders    0
# Sales_boost       0
# Invoice           0
# StockCode         0
# Quantity          0
# Price             0
# Customer_Id       0
# Hour              0
# Month             0
# Year              0
# Day               0
# Weeknumber        0
# dtype: int64

# %%
all_results = []
    
# initialize setup from pycaret.regression
s = setup(df, target ='Post_30_orders' , train_size = 0.8,
              data_split_shuffle = True, fold = 5,
              ignore_features = ['Invoice','StockCode'],
              numeric_features = ['counts', 'TotalPrice', 'Average_Price', 'Pre_wk_orders','Pre_30_orders', 
               'Month','Year', 'Day', 'Weeknumber'],
              silent = True, verbose = False, session_id = 123, normalize=False)

best = compare_models()
best
# Out:
# <style type="text/css">
# #T_929d6_ th {
#   text-align: left;
# }
# #T_929d6_row0_col0, #T_929d6_row1_col0, #T_929d6_row1_col3, #T_929d6_row2_col0, #T_929d6_row3_col0, #T_929d6_row3_col1, #T_929d6_row3_col2, #T_929d6_row3_col3, #T_929d6_row3_col4, #T_929d6_row3_col5, #T_929d6_row3_col6, #T_929d6_row4_col0, #T_929d6_row4_col1, #T_929d6_row4_col2, #T_929d6_row4_col3, #T_929d6_row4_col4, #T_929d6_row4_col5, #T_929d6_row4_col6, #T_929d6_row5_col0, #T_929d6_row5_col1, #T_929d6_row5_col2, #T_929d6_row5_col3, #T_929d6_row5_col4, #T_929d6_row5_col5, #T_929d6_row5_col6, #T_929d6_row6_col0, #T_929d6_row6_col1, #T_929d6_row6_col2, #T_929d6_row6_col3, #T_929d6_row6_col4, #T_929d6_row6_col5, #T_929d6_row6_col6, #T_929d6_row7_col0, #T_929d6_row7_col1, #T_929d6_row7_col2, #T_929d6_row7_col3, #T_929d6_row7_col4, #T_929d6_row7_col5, #T_929d6_row7_col6, #T_929d6_row8_col0, #T_929d6_row8_col1, #T_929d6_row8_col2, #T_929d6_row8_col3, #T_929d6_row8_col4, #T_929d6_row8_col5, #T_929d6_row8_col6, #T_929d6_row9_col0, #T_929d6_row9_col1, #T_929d6_row9_col2, #T_929d6_row9_col3, #T_929d6_row9_col4, #T_929d6_row9_col5, #T_929d6_row9_col6, #T_929d6_row10_col0, #T_929d6_row10_col1, #T_929d6_row10_col2, #T_929d6_row10_col3, #T_929d6_row10_col4, #T_929d6_row10_col5, #T_929d6_row10_col6, #T_929d6_row11_col0, #T_929d6_row11_col1, #T_929d6_row11_col2, #T_929d6_row11_col3, #T_929d6_row11_col4, #T_929d6_row11_col5, #T_929d6_row11_col6, #T_929d6_row12_col0, #T_929d6_row12_col1, #T_929d6_row12_col2, #T_929d6_row12_col3, #T_929d6_row12_col4, #T_929d6_row12_col5, #T_929d6_row12_col6, #T_929d6_row13_col0, #T_929d6_row13_col1, #T_929d6_row13_col2, #T_929d6_row13_col3, #T_929d6_row13_col4, #T_929d6_row13_col5, #T_929d6_row13_col6, #T_929d6_row14_col0, #T_929d6_row14_col1, #T_929d6_row14_col2, #T_929d6_row14_col3, #T_929d6_row14_col4, #T_929d6_row14_col5, #T_929d6_row14_col6, #T_929d6_row15_col0, #T_929d6_row15_col1, #T_929d6_row15_col2, #T_929d6_row15_col3, #T_929d6_row15_col4, #T_929d6_row15_col5, #T_929d6_row15_col6, #T_929d6_row16_col0, #T_929d6_row16_col1, #T_929d6_row16_col2, #T_929d6_row16_col3, #T_929d6_row16_col4, #T_929d6_row16_col5, #T_929d6_row16_col6 {
#   text-align: left;
# }
# #T_929d6_row0_col1, #T_929d6_row0_col2, #T_929d6_row0_col3, #T_929d6_row0_col4, #T_929d6_row0_col5, #T_929d6_row0_col6, #T_929d6_row1_col1, #T_929d6_row1_col2, #T_929d6_row1_col4, #T_929d6_row1_col5, #T_929d6_row1_col6, #T_929d6_row2_col1, #T_929d6_row2_col2, #T_929d6_row2_col3, #T_929d6_row2_col4, #T_929d6_row2_col5, #T_929d6_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_929d6_row0_col7, #T_929d6_row1_col7, #T_929d6_row2_col7, #T_929d6_row3_col7, #T_929d6_row4_col7, #T_929d6_row5_col7, #T_929d6_row6_col7, #T_929d6_row7_col7, #T_929d6_row8_col7, #T_929d6_row9_col7, #T_929d6_row10_col7, #T_929d6_row11_col7, #T_929d6_row12_col7, #T_929d6_row13_col7, #T_929d6_row14_col7, #T_929d6_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_929d6_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_929d6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_929d6_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_929d6_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_929d6_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_929d6_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_929d6_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_929d6_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_929d6_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_929d6_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_929d6_row0_col7" class="data row0 col7" >0.7060</td>
#     </tr>
#     <tr>
#       <th id="T_929d6_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_929d6_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_929d6_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_929d6_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_929d6_row1_col3" class="data row1 col3" >0.0007</td>
#       <td id="T_929d6_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_929d6_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_929d6_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_929d6_row1_col7" class="data row1 col7" >25.4020</td>
#     </tr>
#     <tr>
#       <th id="T_929d6_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_929d6_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_929d6_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_929d6_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_929d6_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_929d6_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_929d6_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_929d6_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_929d6_row2_col7" class="data row2 col7" >34.1460</td>
#     </tr>
#     <tr>
#       <th id="T_929d6_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_929d6_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_929d6_row3_col1" class="data row3 col1" >5.2186</td>
#       <td id="T_929d6_row3_col2" class="data row3 col2" >46.0786</td>
#       <td id="T_929d6_row3_col3" class="data row3 col3" >6.7861</td>
#       <td id="T_929d6_row3_col4" class="data row3 col4" >0.9998</td>
#       <td id="T_929d6_row3_col5" class="data row3 col5" >0.0076</td>
#       <td id="T_929d6_row3_col6" class="data row3 col6" >0.0029</td>
#       <td id="T_929d6_row3_col7" class="data row3 col7" >1.8340</td>
#     </tr>
#     <tr>
#       <th id="T_929d6_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_929d6_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#       <td id="T_929d6_row4_col1" class="data row4 col1" >0.7839</td>
#       <td id="T_929d6_row4_col2" class="data row4 col2" >232.3094</td>
#       <td id="T_929d6_row4_col3" class="data row4 col3" >15.2028</td>
#       <td id="T_929d6_row4_col4" class="data row4 col4" >0.9992</td>
#       <td id="T_929d6_row4_col5" class="data row4 col5" >0.0104</td>
#       <td id="T_929d6_row4_col6" class="data row4 col6" >0.0006</td>
#       <td id="T_929d6_row4_col7" class="data row4 col7" >8.8500</td>
#     </tr>
#     <tr>
#       <th id="T_929d6_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_929d6_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_929d6_row5_col1" class="data row5 col1" >33.6618</td>
#       <td id="T_929d6_row5_col2" class="data row5 col2" >1898.5529</td>
#       <td id="T_929d6_row5_col3" class="data row5 col3" >43.5494</td>
#       <td id="T_929d6_row5_col4" class="data row5 col4" >0.9936</td>
#       <td id="T_929d6_row5_col5" class="data row5 col5" >0.0384</td>
#       <td id="T_929d6_row5_col6" class="data row5 col6" >0.0187</td>
#       <td id="T_929d6_row5_col7" class="data row5 col7" >24.9400</td>
#     </tr>
#     <tr>
#       <th id="T_929d6_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_929d6_row6_col0" class="data row6 col0" >AdaBoost Regressor</td>
#       <td id="T_929d6_row6_col1" class="data row6 col1" >130.0043</td>
#       <td id="T_929d6_row6_col2" class="data row6 col2" >23833.7808</td>
#       <td id="T_929d6_row6_col3" class="data row6 col3" >154.3700</td>
#       <t
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=123, splitter='best')

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_134e2_row5_col0, #T_134e2_row5_col1, #T_134e2_row5_col2, #T_134e2_row5_col3, #T_134e2_row5_col4, #T_134e2_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_134e2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_134e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_134e2_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_134e2_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_134e2_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_134e2_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_134e2_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_134e2_row0_col5" class="data row0 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_134e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_134e2_row1_col0" class="data row1 col0" >0.0000</td>
#       <td id="T_134e2_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_134e2_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_134e2_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_134e2_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_134e2_row1_col5" class="data row1 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_134e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_134e2_row2_col0" class="data row2 col0" >0.0000</td>
#       <td id="T_134e2_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_134e2_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_134e2_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_134e2_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_134e2_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_134e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_134e2_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_134e2_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_134e2_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_134e2_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_134e2_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_134e2_row3_col5" class="data row3 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_134e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_134e2_row4_col0" class="data row4 col0" >0.0000</td>
#       <td id="T_134e2_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_134e2_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_134e2_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_134e2_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_134e2_row4_col5" class="data row4 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_134e2_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_134e2_row5_col0" class="data row5 col0" >0.0000</td>
#       <td id="T_134e2_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_134e2_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_134e2_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_134e2_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_134e2_row5_col5" class="data row5 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_134e2_level0_row6" class="row_heading level0 row6" >SD</th>
#       <td id="T_134e2_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_134e2_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_134e2_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_134e2_row6_col3" class="data row6 col3" >0.0000</td>
#       <td id="T_134e2_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_134e2_row6_col5" class="data row6 col5" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
save_model(rf, '../models/orders_post30_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False,
#                                        features_todrop=['Invoice', 'StockCode'],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['counts',
#                                                            'TotalPrice',
#                                                            'Average_Price',
#                                                            'Pre_wk_orders',
#                                                            'Pre_30_orders',
#                                                            'Month', 'Year',
#                                                            'Day', 'Weeknumber'],
#                                        target='Post_30_orders',
#                                        time_features=[])),
#                  (...
#                   RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                         criterion='mse', max_depth=None,
#                                         max_features='auto', max_leaf_nodes=None,
#                                         max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=-1,
#                                         oob_score=False, random_state=123,
#                                         verbose=0, warm_start=False)]],
#           verbose=False),
#  '../models/orders_post30_model.pkl')

# %%
df_nonuk = pd.read_csv('../data/processed/Final_EDA_NonUK.csv')

# %%
final_df = df[['counts','TotalPrice','Average_Price','Pre_wk_orders','Pre_30_orders','Month', 'Year','Day', 'Weeknumber','Post_30_orders']]
final_df_nonuk = df_nonuk[['counts','TotalPrice','Average_Price','Pre_wk_orders','Pre_30_orders','Month', 'Year','Day', 'Weeknumber','Post_30_orders']]

# %%
final_df.shape
# Out:
# (741255, 10)

# %%
final_df = final_df[final_df.Average_Price >= 0.0]
final_df_nonuk = final_df_nonuk[final_df_nonuk.Average_Price >= 0.0]

# %%
final_df.to_csv('..\models\Final_Features.csv', index=False)
final_df_nonuk.to_csv('..\models\Final_Features_NonUK.csv', index=False)

# %%
all_results = []
    
# initialize setup from pycaret.regression
s = setup(df_nonuk, target ='Post_30_orders' , train_size = 0.8,
              data_split_shuffle = True, fold = 5,
              ignore_features = ['Invoice','StockCode'],
              numeric_features = ['counts', 'TotalPrice', 'Average_Price', 'Pre_wk_orders','Pre_30_orders', 
               'Month','Year', 'Day', 'Weeknumber'],
              silent = True, verbose = False, session_id = 123, normalize=False)

best = compare_models()
best
# Out:
# <style type="text/css">
# #T_ceb7e_ th {
#   text-align: left;
# }
# #T_ceb7e_row0_col0, #T_ceb7e_row1_col0, #T_ceb7e_row1_col1, #T_ceb7e_row1_col2, #T_ceb7e_row1_col3, #T_ceb7e_row1_col5, #T_ceb7e_row2_col0, #T_ceb7e_row2_col1, #T_ceb7e_row2_col2, #T_ceb7e_row2_col3, #T_ceb7e_row2_col5, #T_ceb7e_row3_col0, #T_ceb7e_row3_col1, #T_ceb7e_row3_col2, #T_ceb7e_row3_col3, #T_ceb7e_row3_col4, #T_ceb7e_row3_col5, #T_ceb7e_row3_col6, #T_ceb7e_row4_col0, #T_ceb7e_row4_col1, #T_ceb7e_row4_col2, #T_ceb7e_row4_col3, #T_ceb7e_row4_col4, #T_ceb7e_row4_col5, #T_ceb7e_row4_col6, #T_ceb7e_row5_col0, #T_ceb7e_row5_col1, #T_ceb7e_row5_col2, #T_ceb7e_row5_col3, #T_ceb7e_row5_col4, #T_ceb7e_row5_col5, #T_ceb7e_row5_col6, #T_ceb7e_row6_col0, #T_ceb7e_row6_col1, #T_ceb7e_row6_col2, #T_ceb7e_row6_col3, #T_ceb7e_row6_col4, #T_ceb7e_row6_col5, #T_ceb7e_row6_col6, #T_ceb7e_row7_col0, #T_ceb7e_row7_col1, #T_ceb7e_row7_col2, #T_ceb7e_row7_col3, #T_ceb7e_row7_col4, #T_ceb7e_row7_col5, #T_ceb7e_row7_col6, #T_ceb7e_row8_col0, #T_ceb7e_row8_col1, #T_ceb7e_row8_col2, #T_ceb7e_row8_col3, #T_ceb7e_row8_col4, #T_ceb7e_row8_col5, #T_ceb7e_row8_col6, #T_ceb7e_row9_col0, #T_ceb7e_row9_col1, #T_ceb7e_row9_col2, #T_ceb7e_row9_col3, #T_ceb7e_row9_col4, #T_ceb7e_row9_col5, #T_ceb7e_row9_col6, #T_ceb7e_row10_col0, #T_ceb7e_row10_col1, #T_ceb7e_row10_col2, #T_ceb7e_row10_col3, #T_ceb7e_row10_col4, #T_ceb7e_row10_col5, #T_ceb7e_row10_col6, #T_ceb7e_row11_col0, #T_ceb7e_row11_col1, #T_ceb7e_row11_col2, #T_ceb7e_row11_col3, #T_ceb7e_row11_col4, #T_ceb7e_row11_col5, #T_ceb7e_row11_col6, #T_ceb7e_row12_col0, #T_ceb7e_row12_col1, #T_ceb7e_row12_col2, #T_ceb7e_row12_col3, #T_ceb7e_row12_col4, #T_ceb7e_row12_col5, #T_ceb7e_row12_col6, #T_ceb7e_row13_col0, #T_ceb7e_row13_col1, #T_ceb7e_row13_col2, #T_ceb7e_row13_col3, #T_ceb7e_row13_col4, #T_ceb7e_row13_col5, #T_ceb7e_row13_col6, #T_ceb7e_row14_col0, #T_ceb7e_row14_col1, #T_ceb7e_row14_col2, #T_ceb7e_row14_col3, #T_ceb7e_row14_col4, #T_ceb7e_row14_col5, #T_ceb7e_row14_col6, #T_ceb7e_row15_col0, #T_ceb7e_row15_col1, #T_ceb7e_row15_col2, #T_ceb7e_row15_col3, #T_ceb7e_row15_col4, #T_ceb7e_row15_col5, #T_ceb7e_row15_col6, #T_ceb7e_row16_col0, #T_ceb7e_row16_col1, #T_ceb7e_row16_col2, #T_ceb7e_row16_col3, #T_ceb7e_row16_col4, #T_ceb7e_row16_col5, #T_ceb7e_row16_col6 {
#   text-align: left;
# }
# #T_ceb7e_row0_col1, #T_ceb7e_row0_col2, #T_ceb7e_row0_col3, #T_ceb7e_row0_col4, #T_ceb7e_row0_col5, #T_ceb7e_row0_col6, #T_ceb7e_row1_col4, #T_ceb7e_row1_col6, #T_ceb7e_row2_col4, #T_ceb7e_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ceb7e_row0_col7, #T_ceb7e_row1_col7, #T_ceb7e_row2_col7, #T_ceb7e_row3_col7, #T_ceb7e_row4_col7, #T_ceb7e_row5_col7, #T_ceb7e_row6_col7, #T_ceb7e_row7_col7, #T_ceb7e_row8_col7, #T_ceb7e_row9_col7, #T_ceb7e_row10_col7, #T_ceb7e_row11_col7, #T_ceb7e_row12_col7, #T_ceb7e_row13_col7, #T_ceb7e_row14_col7, #T_ceb7e_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ceb7e_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ceb7e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ceb7e_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_ceb7e_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_ceb7e_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_ceb7e_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_ceb7e_row0_col3" class="data row0 col3" >0.0025</td>
#       <td id="T_ceb7e_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_ceb7e_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_ceb7e_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_ceb7e_row0_col7" class="data row0 col7" >0.0760</td>
#     </tr>
#     <tr>
#       <th id="T_ceb7e_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_ceb7e_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_ceb7e_row1_col1" class="data row1 col1" >0.0003</td>
#       <td id="T_ceb7e_row1_col2" class="data row1 col2" >0.0002</td>
#       <td id="T_ceb7e_row1_col3" class="data row1 col3" >0.0139</td>
#       <td id="T_ceb7e_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_ceb7e_row1_col5" class="data row1 col5" >0.0001</td>
#       <td id="T_ceb7e_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_ceb7e_row1_col7" class="data row1 col7" >0.9440</td>
#     </tr>
#     <tr>
#       <th id="T_ceb7e_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_ceb7e_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_ceb7e_row2_col1" class="data row2 col1" >0.0010</td>
#       <td id="T_ceb7e_row2_col2" class="data row2 col2" >0.0035</td>
#       <td id="T_ceb7e_row2_col3" class="data row2 col3" >0.0553</td>
#       <td id="T_ceb7e_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_ceb7e_row2_col5" class="data row2 col5" >0.0002</td>
#       <td id="T_ceb7e_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_ceb7e_row2_col7" class="data row2 col7" >1.7060</td>
#     </tr>
#     <tr>
#       <th id="T_ceb7e_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_ceb7e_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ceb7e_row3_col1" class="data row3 col1" >0.7239</td>
#       <td id="T_ceb7e_row3_col2" class="data row3 col2" >0.9399</td>
#       <td id="T_ceb7e_row3_col3" class="data row3 col3" >0.9694</td>
#       <td id="T_ceb7e_row3_col4" class="data row3 col4" >0.9998</td>
#       <td id="T_ceb7e_row3_col5" class="data row3 col5" >0.0063</td>
#       <td id="T_ceb7e_row3_col6" class="data row3 col6" >0.0035</td>
#       <td id="T_ceb7e_row3_col7" class="data row3 col7" >0.3740</td>
#     </tr>
#     <tr>
#       <th id="T_ceb7e_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_ceb7e_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#       <td id="T_ceb7e_row4_col1" class="data row4 col1" >0.4089</td>
#       <td id="T_ceb7e_row4_col2" class="data row4 col2" >21.2284</td>
#       <td id="T_ceb7e_row4_col3" class="data row4 col3" >4.5988</td>
#       <td id="T_ceb7e_row4_col4" class="data row4 col4" >0.9947</td>
#       <td id="T_ceb7e_row4_col5" class="data row4 col5" >0.0226</td>
#       <td id="T_ceb7e_row4_col6" class="data row4 col6" >0.0020</td>
#       <td id="T_ceb7e_row4_col7" class="data row4 col7" >0.1340</td>
#     </tr>
#     <tr>
#       <th id="T_ceb7e_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_ceb7e_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ceb7e_row5_col1" class="data row5 col1" >4.4531</td>
#       <td id="T_ceb7e_row5_col2" class="data row5 col2" >37.5099</td>
#       <td id="T_ceb7e_row5_col3" class="data row5 col3" >6.1231</td>
#       <td id="T_ceb7e_row5_col4" class="data row5 col4" >0.9906</td>
#       <td id="T_ceb7e_row5_col5" class="data row5 col5" >0.0395</td>
#       <td id="T_ceb7e_row5_col6" class="data row5 col6" >0.0219</td>
#       <td id="T_ceb7e_row5_col7" class="data row5 col7" >1.6080</td>
#     </tr>
#     <tr>
#       <th id="T_ceb7e_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_ceb7e_row6_col0" class="data row6 col0" >AdaBoost Regressor</td>
#       <td id="T_ceb7e_row6_col1" class="data row6 col1" >11.0162</td>
#       <td id="T_ceb7e_row6_col2" class="data row6 col2" >198.6108</td>
#       <td id="T_ceb7e_row6_col3" class="data row6 col3" >14.0897</td>
#       <td id="T_ceb7e_
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=123, splitter='best')

# %%
new_df = df_nonuk.append(df)
new_df.shape
# Out:
# (824293, 18)

# %%
# initialize setup from pycaret.regression
s = setup(new_df, target ='Post_30_orders' , train_size = 0.8,
              data_split_shuffle = True, fold = 5,
              ignore_features = ['Invoice','StockCode'],
              numeric_features = ['counts', 'TotalPrice', 'Average_Price', 'Pre_wk_orders','Pre_30_orders', 
               'Month','Year', 'Day', 'Weeknumber'],
              silent = True, verbose = False, session_id = 123, normalize=False)

best = compare_models()
best
# Out:
# <style type="text/css">
# #T_46adb_ th {
#   text-align: left;
# }
# #T_46adb_row0_col0, #T_46adb_row0_col2, #T_46adb_row1_col0, #T_46adb_row1_col1, #T_46adb_row1_col2, #T_46adb_row1_col3, #T_46adb_row2_col0, #T_46adb_row2_col3, #T_46adb_row3_col0, #T_46adb_row3_col1, #T_46adb_row3_col2, #T_46adb_row3_col3, #T_46adb_row3_col4, #T_46adb_row3_col5, #T_46adb_row3_col6, #T_46adb_row4_col0, #T_46adb_row4_col1, #T_46adb_row4_col2, #T_46adb_row4_col3, #T_46adb_row4_col4, #T_46adb_row4_col5, #T_46adb_row4_col6, #T_46adb_row5_col0, #T_46adb_row5_col1, #T_46adb_row5_col2, #T_46adb_row5_col3, #T_46adb_row5_col4, #T_46adb_row5_col5, #T_46adb_row5_col6, #T_46adb_row6_col0, #T_46adb_row6_col1, #T_46adb_row6_col2, #T_46adb_row6_col3, #T_46adb_row6_col4, #T_46adb_row6_col5, #T_46adb_row6_col6, #T_46adb_row7_col0, #T_46adb_row7_col1, #T_46adb_row7_col2, #T_46adb_row7_col3, #T_46adb_row7_col4, #T_46adb_row7_col5, #T_46adb_row7_col6, #T_46adb_row8_col0, #T_46adb_row8_col1, #T_46adb_row8_col2, #T_46adb_row8_col3, #T_46adb_row8_col4, #T_46adb_row8_col5, #T_46adb_row8_col6, #T_46adb_row9_col0, #T_46adb_row9_col1, #T_46adb_row9_col2, #T_46adb_row9_col3, #T_46adb_row9_col4, #T_46adb_row9_col5, #T_46adb_row9_col6, #T_46adb_row10_col0, #T_46adb_row10_col1, #T_46adb_row10_col2, #T_46adb_row10_col3, #T_46adb_row10_col4, #T_46adb_row10_col5, #T_46adb_row10_col6, #T_46adb_row11_col0, #T_46adb_row11_col1, #T_46adb_row11_col2, #T_46adb_row11_col3, #T_46adb_row11_col4, #T_46adb_row11_col5, #T_46adb_row11_col6, #T_46adb_row12_col0, #T_46adb_row12_col1, #T_46adb_row12_col2, #T_46adb_row12_col3, #T_46adb_row12_col4, #T_46adb_row12_col5, #T_46adb_row12_col6, #T_46adb_row13_col0, #T_46adb_row13_col1, #T_46adb_row13_col2, #T_46adb_row13_col3, #T_46adb_row13_col4, #T_46adb_row13_col5, #T_46adb_row13_col6, #T_46adb_row14_col0, #T_46adb_row14_col1, #T_46adb_row14_col2, #T_46adb_row14_col3, #T_46adb_row14_col4, #T_46adb_row14_col5, #T_46adb_row14_col6, #T_46adb_row15_col0, #T_46adb_row15_col1, #T_46adb_row15_col2, #T_46adb_row15_col3, #T_46adb_row15_col4, #T_46adb_row15_col5, #T_46adb_row15_col6, #T_46adb_row16_col0, #T_46adb_row16_col1, #T_46adb_row16_col2, #T_46adb_row16_col3, #T_46adb_row16_col4, #T_46adb_row16_col5, #T_46adb_row16_col6 {
#   text-align: left;
# }
# #T_46adb_row0_col1, #T_46adb_row0_col3, #T_46adb_row0_col4, #T_46adb_row0_col5, #T_46adb_row0_col6, #T_46adb_row1_col4, #T_46adb_row1_col5, #T_46adb_row1_col6, #T_46adb_row2_col1, #T_46adb_row2_col2, #T_46adb_row2_col4, #T_46adb_row2_col5, #T_46adb_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_46adb_row0_col7, #T_46adb_row1_col7, #T_46adb_row2_col7, #T_46adb_row3_col7, #T_46adb_row4_col7, #T_46adb_row5_col7, #T_46adb_row6_col7, #T_46adb_row7_col7, #T_46adb_row8_col7, #T_46adb_row9_col7, #T_46adb_row10_col7, #T_46adb_row11_col7, #T_46adb_row12_col7, #T_46adb_row13_col7, #T_46adb_row14_col7, #T_46adb_row15_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_46adb_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_46adb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46adb_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_46adb_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_46adb_row0_col1" class="data row0 col1" >0.0001</td>
#       <td id="T_46adb_row0_col2" class="data row0 col2" >0.0019</td>
#       <td id="T_46adb_row0_col3" class="data row0 col3" >0.0193</td>
#       <td id="T_46adb_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_46adb_row0_col5" class="data row0 col5" >0.0001</td>
#       <td id="T_46adb_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_46adb_row0_col7" class="data row0 col7" >0.9540</td>
#     </tr>
#     <tr>
#       <th id="T_46adb_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_46adb_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_46adb_row1_col1" class="data row1 col1" >0.0002</td>
#       <td id="T_46adb_row1_col2" class="data row1 col2" >0.0018</td>
#       <td id="T_46adb_row1_col3" class="data row1 col3" >0.0249</td>
#       <td id="T_46adb_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_46adb_row1_col5" class="data row1 col5" >0.0001</td>
#       <td id="T_46adb_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_46adb_row1_col7" class="data row1 col7" >33.8060</td>
#     </tr>
#     <tr>
#       <th id="T_46adb_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_46adb_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_46adb_row2_col1" class="data row2 col1" >0.0001</td>
#       <td id="T_46adb_row2_col2" class="data row2 col2" >0.0011</td>
#       <td id="T_46adb_row2_col3" class="data row2 col3" >0.0203</td>
#       <td id="T_46adb_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_46adb_row2_col5" class="data row2 col5" >0.0001</td>
#       <td id="T_46adb_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_46adb_row2_col7" class="data row2 col7" >46.0240</td>
#     </tr>
#     <tr>
#       <th id="T_46adb_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_46adb_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_46adb_row3_col1" class="data row3 col1" >8.2987</td>
#       <td id="T_46adb_row3_col2" class="data row3 col2" >118.4782</td>
#       <td id="T_46adb_row3_col3" class="data row3 col3" >10.8812</td>
#       <td id="T_46adb_row3_col4" class="data row3 col4" >0.9998</td>
#       <td id="T_46adb_row3_col5" class="data row3 col5" >0.0391</td>
#       <td id="T_46adb_row3_col6" class="data row3 col6" >0.0106</td>
#       <td id="T_46adb_row3_col7" class="data row3 col7" >2.5200</td>
#     </tr>
#     <tr>
#       <th id="T_46adb_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_46adb_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#       <td id="T_46adb_row4_col1" class="data row4 col1" >0.8124</td>
#       <td id="T_46adb_row4_col2" class="data row4 col2" >244.7475</td>
#       <td id="T_46adb_row4_col3" class="data row4 col3" >15.6245</td>
#       <td id="T_46adb_row4_col4" class="data row4 col4" >0.9996</td>
#       <td id="T_46adb_row4_col5" class="data row4 col5" >0.0144</td>
#       <td id="T_46adb_row4_col6" class="data row4 col6" >0.0008</td>
#       <td id="T_46adb_row4_col7" class="data row4 col7" >4.8740</td>
#     </tr>
#     <tr>
#       <th id="T_46adb_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_46adb_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_46adb_row5_col1" class="data row5 col1" >58.5551</td>
#       <td id="T_46adb_row5_col2" class="data row5 col2" >5985.0958</td>
#       <td id="T_46adb_row5_col3" class="data row5 col3" >77.3598</td>
#       <td id="T_46adb_row5_col4" class="data row5 col4" >0.9898</td>
#       <td id="T_46adb_row5_col5" class="data row5 col5" >0.1135</td>
#       <td id="T_46adb_row5_col6" class="data row5 col6" >0.0560</td>
#       <td id="T_46adb_row5_col7" class="data row5 col7" >32.6980</td>
#     </tr>
#     <tr>
#       <th id="T_46adb_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_46adb_row6_col0" class="data row6 col0" >AdaBoost Regressor</td>
#       <td id="T_46adb_row6_col1" class="data row6 col1" >160.2473</td>
#       <td id="T_46adb_row6_col2" class="data row6 col2" >41095.3522</td>
#       <td id="T_46adb_row6_col3" class="data row6 col3" >202.6111</td>
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=123, splitter='best')
